# %%
import pandas as pd
df = pd.read_csv("sales_data.csv")
df.head()
# Out:
#    Order_ID  Order_Date Customer_Name Region     Product     Category  \
# 0      1001  2024-01-05         Rahul   West      Laptop  Electronics
# 1      1002  2024-01-07          Neha  North      Mobile  Electronics
# 2      1003  2024-02-10          Amit  South       Chair    Furniture
# 3      1004  2024-02-15         Pooja   East       Table    Furniture
# 4      1005  2024-03-01          Ravi   West  Headphones  Electronics
#
#    Quantity  Price
# 0         2  55000
# 1         1  20000
# 2         4   2500
# 3         2   7000
# 4         3   1500

# %%
import pandas as pd
df = pd.read_csv("sales_data.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order_ID       10 non-null     int64
#  1   Order_Date     10 non-null     object
#  2   Customer_Name  10 non-null     object
#  3   Region         10 non-null     object
#  4   Product        10 non-null     object
#  5   Category       10 non-null     object
#  6   Quantity       10 non-null     int64
#  7   Price          10 non-null     int64
# dtypes: int64(3), object(5)
# memory usage: 772.0+ bytes

# %%
import pandas as pd
df = pd.read_csv("sales_data.csv")
df.describe()
# Out:
#          Order_ID   Quantity         Price
# count    10.00000  10.000000     10.000000
# mean   1005.50000   2.400000  20050.000000
# std       3.02765   1.349897  20663.238963
# min    1001.00000   1.000000   1500.000000
# 25%    1003.25000   1.250000   3625.000000
# 50%    1005.50000   2.000000  13500.000000
# 75%    1007.75000   3.000000  27500.000000
# max    1010.00000   5.000000  55000.000000

# %%
import pandas as pd
df = pd.read_csv("sales_data.csv")
df.isnull().sum()
# Out:
# Order_ID         0
# Order_Date       0
# Customer_Name    0
# Region           0
# Product          0
# Category         0
# Quantity         0
# Price            0
# dtype: int64

# %%
import pandas as pd
df = pd.read_csv("sales_data.csv")
df.columns
# Out:
# Index(['Order_ID', 'Order_Date', 'Customer_Name', 'Region', 'Product',
#        'Category', 'Quantity', 'Price'],
#       dtype='object')

# %%
import pandas as pd

df = pd.read_csv("sales_data.csv")

df["Total_Sales"] = df["Quantity"] * df["Price"]

df.head()
# Out:
#    Order_ID  Order_Date Customer_Name Region     Product     Category  \
# 0      1001  2024-01-05         Rahul   West      Laptop  Electronics
# 1      1002  2024-01-07          Neha  North      Mobile  Electronics
# 2      1003  2024-02-10          Amit  South       Chair    Furniture
# 3      1004  2024-02-15         Pooja   East       Table    Furniture
# 4      1005  2024-03-01          Ravi   West  Headphones  Electronics
#
#    Quantity  Price  Total_Sales
# 0         2  55000       110000
# 1         1  20000        20000
# 2         4   2500        10000
# 3         2   7000        14000
# 4         3   1500         4500

# %%
import pandas as pd

df = pd.read_csv("sales_data.csv")

df["Total_Sales"] = df["Quantity"] * df["Price"]
df["Total_Sales"].sum()
# Out:
# np.int64(317000)

# %%
import pandas as pd

df = pd.read_csv("sales_data.csv")

df["Total_Sales"] = df["Quantity"] * df["Price"]

df.head()
# Out:
#    Order_ID  Order_Date Customer_Name Region     Product     Category  \
# 0      1001  2024-01-05         Rahul   West      Laptop  Electronics
# 1      1002  2024-01-07          Neha  North      Mobile  Electronics
# 2      1003  2024-02-10          Amit  South       Chair    Furniture
# 3      1004  2024-02-15         Pooja   East       Table    Furniture
# 4      1005  2024-03-01          Ravi   West  Headphones  Electronics
#
#    Quantity  Price  Total_Sales
# 0         2  55000       110000
# 1         1  20000        20000
# 2         4   2500        10000
# 3         2   7000        14000
# 4         3   1500         4500

# %%
import pandas as pd

df = pd.read_csv("sales_data.csv")

df["Total_Sales"] = df["Quantity"] * df["Price"]
df.groupby("Region")["Total_Sales"].sum()
# Out:
# Region
# East      54000
# North     96000
# South     40000
# West     127000
# Name: Total_Sales, dtype: int64

# %%
import pandas as pd
df = pd.read_csv("sales_data.csv")
df["Total_sales"] = df["Quantity"] * df["Price"]
df.sort_values("Total_sales", ascending = False).head()
# Out:
#    Order_ID  Order_Date Customer_Name Region Product     Category  Quantity  \
# 0      1001  2024-01-05         Rahul   West  Laptop  Electronics         2
# 5      1006  2024-03-05        Anjali  North  Laptop  Electronics         1
# 7      1008  2024-04-12         Kiran   East  Mobile  Electronics         2
# 6      1007  2024-04-10         Sunil  South    Sofa    Furniture         1
# 9      1010  2024-05-15         Arjun  North   Table    Furniture         3
#
#    Price  Total_sales
# 0  55000       110000
# 5  55000        55000
# 7  20000        40000
# 6  30000        30000
# 9   7000        21000

# %%
import pandas as pd
df = pd.read_csv("sales_data.csv")
df["Total_sales"] = df["Quantity"] * df["Price"]
df["Total_sales"].mean()
# Out:
# np.float64(31700.0)

# %%
import pandas as pd
df = pd.read_csv("sales_data.csv")
df["Total_sales"] = df["Quantity"] * df["Price"]
df.shape
# Out:
# (10, 9)

# %%
import pandas as pd
df = pd.read_csv("sales_data.csv")
df["Total_sales"] = df["Quantity"] * df["Price"]
df.groupby("Region")["Total_sales"].mean()
# Out:
# Region
# East     27000.000000
# North    32000.000000
# South    20000.000000
# West     42333.333333
# Name: Total_sales, dtype: float64

# %%
import matplotlib.pyplot as plt

df["Total_Sales"] = df["Quantity"] * df["Price"]

region_sales = df.groupby("Region")["Total_Sales"].sum()

plt.figure()
region_sales.plot(kind="bar")

plt.title("Total Sales by Region")
plt.xlabel("Region")
plt.ylabel("Total Sales")

plt.show()

# %%
import matplotlib.pyplot as plt

df["Total_Sales"] = df["Quantity"] * df["Price"]
product_sales = df.groupby("Product")["Total_Sales"].sum()

plt.figure()
product_sales.plot(kind="bar")

plt.title("Total Sales by Product")
plt.xlabel("Product")
plt.ylabel("Total Sales")

plt.show()

# %%
import matplotlib.pyplot as plt
df["Tota_sales"] = df["Quantity"] * df["Price"]
Product_sales = df.groupby("Product")["Total_sales"].mean().sort_values(ascending=False)
plt.figure()
Product_sales.plot(kind="bar")
plt.title("Total sales of product")
plt.xlabel("Product")
plt.ylabel("Total sales")
plt.show()

# %%
import matplotlib.pyplot as plt
df["Tota_sales"] = df["Quantity"] * df["Price"]
Product_sales = df.groupby("Product")["Total_sales"].sum().sort_values(ascending=False)
plt.figure()
Product_sales.plot(kind="bar")
plt.title("Total sales of product")
plt.xlabel("Product")
plt.ylabel("Total sales")
plt.show()

# %%
import matplotlib.pyplot as plt
df["Tota_sales"] = df["Quantity"] * df["Price"]
Product_sales = df[df["Product"] == "Laptop"].groupby("Region")["Total_Sales"].sum()
plt.figure()
Product_sales.plot(kind="bar")
plt.title("Total sales of product")
plt.xlabel("Product")
plt.ylabel("Total sales")
plt.show()

# %%
import pandas as pd

df = pd.read_csv("sales_data.csv")

df["Total_Sales"] = df["Quantity"] * df["Price"]

total_revenue = df["Total_Sales"].sum()

print("Total Revenue:", total_revenue)
# Out:
# Total Revenue: 317000

# %%
import pandas as pd

df = pd.read_csv("sales_data.csv")

df["Total_Sales"] = df["Quantity"] * df["Price"]

total_revenue = df["Total_Sales"].sum()
total_orders = df.shape[0]
average_order_value = df["Total_Sales"].mean()

print("Total Revenue:", total_revenue)
print("Total Orders:", total_orders)
print("Average Order Value:", average_order_value)
# Out:
# Total Revenue: 317000
# Total Orders: 10
# Average Order Value: 31700.0
